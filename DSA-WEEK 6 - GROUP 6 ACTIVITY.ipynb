# %% [markdown]
# # DSA-WEEK 6 - GROUP 6 ACTIVITY

# %% [markdown]
# PARTICIPANTS:-
# 1.SHUHAIB TP,
# 2.ASWIN PHILIP ABRAHAM,
# 3.SHYAMA MOHANAN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Dataset_w6.xlsx')
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %% [markdown]
# # Find out how many countries are there in the dataset

# %%
n = len(pd.unique(data['country']))
print("Number of Countries available in the given dataset is ", n)
# Out:
# Number of Countries available in the given dataset is  196

# %% [markdown]
# # Examine the data by using visualizations

# %%
data1=data[["Region", "Population in thousands (2017)"]].groupby("Region").sum()
data1=pd.DataFrame(data1.sort_values('Population in thousands (2017)', ascending=False))

# %%
data1.plot(kind='bar',figsize=(16,12))
plt.title('Region vs Total Population(2017)', fontsize=22,fontweight="bold")
plt.xlabel('Region', fontsize=16,fontweight="bold")
plt.ylabel('Population', fontsize=16,fontweight="bold")
plt.xticks(fontsize=16,rotation=90)
plt.yticks(np.arange(0,2000000,200000))
plt.legend(loc=1,fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# Southern Asia having highest population with population greater than 1800 million

# %%
data2=data[["Region", "GDP per capita (current US$)"]].groupby("Region").mean()
data2=pd.DataFrame(data2.sort_values('GDP per capita (current US$)', ascending=False))

# %%
data2.plot(kind='bar',figsize=(16,12))
plt.title('Region vs Mean GDP Per Capita(USD)', fontsize=22,fontweight="bold")
plt.xlabel('Region', fontsize=16,fontweight="bold")
plt.ylabel('Mean GDP Per Capita(USD)', fontsize=16,fontweight="bold")
plt.xticks(fontsize=16,rotation=90)
plt.yticks(np.arange(0,60000,4000))
plt.legend(loc=1,fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# Northern America have mean highest Pecapita GDP and Western Africa have lowest

# %%
data3=data[["Region", "Agricultural production index "]].groupby("Region").mean()
data3=pd.DataFrame(data3.sort_values('Agricultural production index ', ascending=False))
data3.plot(kind='bar',figsize=(16,12))
plt.title('Region vs Mean Agricultural Production Index', fontsize=22,fontweight="bold")
plt.xlabel('Region', fontsize=16,fontweight="bold")
plt.ylabel('Mean Agricultural production index', fontsize=16,fontweight="bold")
plt.xticks(fontsize=16,rotation=90)
plt.yticks()
plt.legend(loc=1,fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# South eastern Asia have highest Agricultural production index and Micron asia have lowest

# %%
data4=data[["Region", "International trade: Imports (million US$)"]].groupby("Region").sum()
data4=pd.DataFrame(data4.sort_values('International trade: Imports (million US$)', ascending=False))
data4.plot(kind='bar',figsize=(16,12))
plt.title('Region vs Total International Trade: Imports (million US$)', fontsize=22,fontweight="bold")
plt.xlabel('Region', fontsize=16,fontweight="bold")
plt.ylabel('Total International trade-Imports(million US$)', fontsize=16,fontweight="bold")
plt.xticks(fontsize=16,rotation=90)
plt.yticks()
plt.legend(loc=1,fontsize=16)
plt.grid()
plt.show()

# %% [markdown]
# when considering Total international Trade import Eastern Asia is on Top1 position

# %% [markdown]
# # Find out how many countries with respect to the region are available in the dataset

# %%
df=data[["Region", "country"]].groupby("Region").count()
df.sort_values('country', ascending=False)
# Out:
#                    country
# Region
# WesternAsia             18
# EasternAfrica           17
# Caribbean               16
# WesternAfrica           15
# SouthernEurope          12
# SouthAmerica            12
# South-easternAsia       11
# NorthernEurope          10
# EasternEurope           10
# MiddleAfrica             9
# SouthernAsia             9
# CentralAmerica           8
# EasternAsia              7
# WesternEurope            7
# NorthernAfrica           5
# Polynesia                5
# Melanesia                5
# SouthernAfrica           5
# CentralAsia              5
# NorthernAmerica          4
# Micronesia               4
# Oceania                  2

# %% [markdown]
# Above table shows the count of coutries region wise, Western asia have highest number of countries with 18 countries and Oceania region have lowest number of countries with 2 countries.

# %% [markdown]
# # On average which region has the highest GDP per capita (current US$)

# %%
df1=data[["Region", "GDP per capita (current US$)"]].groupby("Region").mean().reset_index()
df1=pd.DataFrame(df1.sort_values('GDP per capita (current US$)', ascending=False))
print ('On average the below region has the highest GDP per capita (current US$)')
df1.head(1)
# Out:
# On average the below region has the highest GDP per capita (current US$)
#              Region  GDP per capita (current US$)
# 10  NorthernAmerica                       57659.0

# %% [markdown]
# North America is the Region with average highest GDP per capita

# %% [markdown]
# # On average which region has the highest International trade: Imports (million US$)

# %%
df2=data[["Region", "International trade: Imports (million US$)"]].groupby("Region").mean().reset_index()
df2=pd.DataFrame(df2.sort_values('International trade: Imports (million US$)', ascending=False))
print ('On average the below region has the highest International trade: Imports (million US$)')
df2.head(1)
# Out:
# On average the below region has the highest International trade: Imports (million US$)
#              Region  International trade: Imports (million US$)
# 10  NorthernAmerica                                   663552.25

# %%
df3=data[["Region", "International trade: Imports (million US$)"]].groupby("Region").sum().reset_index()
df3=pd.DataFrame(df3.sort_values('International trade: Imports (million US$)', ascending=False))
print ('when considering Total The below region has the highest International trade: Imports (million US$)')
df3.head(1)
# Out:
# when considering Total The below region has the highest International trade: Imports (million US$)
#         Region  International trade: Imports (million US$)
# 4  EasternAsia                                   3163965.0

# %% [markdown]
# When considering average North american region have highest International trade: Imports, but based on total Eastern asia have highest International trade-Imports

# %% [markdown]
# # Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
df4=data[["Region", "GDP per capita (current US$)"]].groupby("Region").std()
df4=pd.DataFrame(df4.sort_values('GDP per capita (current US$)', ascending=False))
print ('The table below shows the standard deviation of of GDP per capita region wise ')
df4
# Out:
# The table below shows the standard deviation of of GDP per capita region wise
#                    GDP per capita (current US$)
# Region
# EasternAsia                        27485.120923
# NorthernAmerica                    25749.619445
# WesternEurope                      24770.467728
# NorthernEurope                     20671.030185
# WesternAsia                        18812.151459
# South-easternAsia                  16311.810656
# Caribbean                          14579.371326
# Melanesia                          13855.842686
# SouthernEurope                      9541.703216
# Oceania                             9233.329638
# Polynesia                           6956.250286
# EasternEurope                       5415.488739
# MiddleAfrica                        5274.846281
# Micronesia                          4820.669694
# SouthAmerica                        4273.707394
# CentralAmerica                      4180.440883
# CentralAsia                         4152.215490
# ...

# %% [markdown]
# The Region with the greatest consistency is the Region with the smallest standard deviation and it is Western Africa
